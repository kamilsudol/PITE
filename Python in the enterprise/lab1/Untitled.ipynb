# %% [markdown]
# Imported libraries:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn.datasets as sk
from sklearn.linear_model import LinearRegression as reg

# %% [markdown]
# Printing a head of data:

# %%
boston_lib = sk.load_boston()
boston_dataFrame = pd.DataFrame(boston_lib.data, columns=boston_lib.feature_names)
pd.options.display.max_columns = None
print(boston_dataFrame.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# Histograms of two chosen columns (I chose CRIM and DIS):

# %%
chosen_two = ["CRIM", "DIS"]
pd.DataFrame.hist(boston_dataFrame, chosen_two, color='k')
plt.show()

# %% [markdown]
# Importing LinearRegression from sklearn module:

# %%
from sklearn.linear_model import LinearRegression as reg

# %% [markdown]
# Plots of data and fitted predictions:

# %%
a = np.array(boston_lib.target) # creating array of target(price) elemets

for i in chosen_two:
    b = np.array(boston_dataFrame[i])  # creating a copy of array
    plt.scatter(b, a, marker='o', color='k' , label='Actual data')  # scattering
    b = b.reshape(-1, 1)  # reshaping our copy of array to make LinearRegression possible
    tmp = reg().fit(b, a.reshape(-1, 1)) # used LinearRegression as reg()
    pred = tmp.predict(b) #predicted values

    # Plot stuff

    plt.xlabel(i)
    plt.ylabel('TARGET(PRICE)')
    plt.grid()
    plt.plot(b, pred, 'r-', label='Prediction')
    plt.legend(loc='upper right')

    plt.show()

# %% [markdown]
# Few words about plots:
#
# For the CRIM plot 'Preditction' line doesn't fit at all. There's too many points, which are too far from our prediction. In my opinion, 'Prediction' line's function, which is y = A*x + B, is good, but to make out prediction more fitted to the points, we shoulde make A ratio less negative otherwise we should take y = A/x function, were A ratio is positive.
#
# On the other hand, for the DIS plot 'Prediction' line is more likely correct than the previous plot. Of course there's many points diffused on the plot, but most of them are located nearly to our prediction line. In this case linear function is correct, but in my opinion to make our prediction line more fitted to the points, we should take logarithm function.
